# %% [markdown]
# <a href="https://colab.research.google.com/github/Waseem-687/Agentic-AI/blob/main/crewai_planning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q -U crewai crewai-tools

# %%
from google.colab import userdata
userdata.get('GOOGLE_API_KEY')
# Out:
# 'AIzaSyAb2cRv2HWqtpzexjH9gROk0wYKNcndy0Q'

# %%
import os
os.environ['GOOGLE_API_KEY'] = userdata.get('GOOGLE_API_KEY')
os.environ["MODEL"] = "gemini/gemini-1.5-flash"

# %%
os.environ["MODEL"]
# Out:
# 'gemini/gemini-1.5-flash'

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
# !crewai create crew project2
# Out:
# Creating folder project2...
# Cache expired or not found. Fetching provider data from the web...
# ...
# Select a provider to set up:
# 1. openai
# 2. anthropic
# 3. gemini
# 4. nvidia_nim
# 5. groq
# 6. ollama
# 7. watson
# 8. bedrock
# 9. azure
# 10. cerebras
# 11. sambanova
# 12. other
# q. Quit
# Enter the number of your choice or 'q' to quit: 3
# Select a model to use for Gemini:
# 1. gemini/gemini-1.5-flash
# 2. gemini/gemini-1.5-pro
# 3. gemini/gemini-gemma-2-9b-it
# 4. gemini/gemini-gemma-2-27b-it
# q. Quit
# Enter the number of your choice or 'q' to quit: 1
# Enter your GEMINI API key (press Enter to skip): AIzaSyB5YcbEZjsRBPIwBheJYxAbrvz6-MPTaEg
# API keys and model saved to .env file
# Selected model: gemini/gemini-1.5-flash
#   - Created project2/.gitignore
#   - Created project2/pyproject.toml
#   - Created project2/README.md
#   - Created project2/knowledge/user_preference.txt
#   - Created project2/src/project2/__init__.py
#   - Created project2/src/project2/main.py
# ...

# %%
pwd
# Out:
# '/content'

# %%
# %cd project2/
# Out:
# /content/project2

# %%
# !ls
# Out:
# knowledge  pyproject.toml  README.md  src  tests

# %%
# !crewai run
# Out:
# Streaming output truncated to the last 5000 lines.
# fastavro   ------------------------------ 2.30 MiB/3.18 MiB
#    Building project2 @ file:///content/project2
# ⠴ Preparing packages... (114/214)
# requests-oauthlib ------------------------------     0 B/23.61 KiB
# referencing ------------------------------ 1.68 KiB/26.15 KiB
# asttokens  ------------------------------ 14.91 KiB/26.29 KiB
# tenacity   ------------------------------ 14.91 KiB/27.51 KiB
# dataclasses-json ------------------------------ 28.01 KiB/28.01 KiB
# google-cloud-core ------------------------------ 28.66 KiB/28.66 KiB
# opentelemetry-instrumentation ------------------------------ 14.93 KiB/30.20 KiB
# google-crc32c ------------------------------ 30.94 KiB/31.73 KiB
# docstring-parser ------------------------------ 32.00 KiB/35.68 KiB
# tzdata     ------------------------------ 270.19 KiB/338.63 KiB
# langchain  ------------------------------ 420.30 KiB/987.87 KiB
# ...

# %%
# !crewai run
# Out:
# Running the Crew
#
# [2025-03-07 19:41:55][INFO]: Planning the crew execution
# # Agent: AI LLMs Senior Data Researcher
# ## Task: Conduct a thorough research about AI LLMs Make sure you find any interesting and relevant information given the current year is 2025.
# 1. **Define Research Scope:** Based on the year 2025, identify key areas of interest within AI LLMs. This includes advancements in model architecture, training methodologies, applications, ethical considerations, and potential societal impacts.
# 2. **Identify Information Sources:** Since no specific tools are available, the agent will rely on general research strategies. Assume access to hypothetical 2025-era resources. This includes academic publications, industry reports, tech blogs, conference proceedings, and news articles focusing on AI.
# ...
